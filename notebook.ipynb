# %% [markdown]
# # 📘 Métodos Numéricos
# Notebook principal del proyecto.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 🔹 Método de Bisección

# %%
import math
from src.root_finding import bisection

f = lambda x: math.cos(x) - x
root = bisection(f, 0, 1)
root

# %% [markdown]
# ## 🔹 Eliminación Gaussiana

# %%
from src.linear_systems import gauss_elimination

A = np.array([[3.0,2.0],[1.0,2.0]])
b = np.array([5.0,3.0])
gauss_elimination(A, b)

# %% [markdown]
# ## 🔹 Integración Numérica

# %%
from src.integration import trapezoid

f = lambda x: x**2
trapezoid(f, 0, 1, 100)

# %% [markdown]
# ## 🔹 Ecuaciones Diferenciales (Euler)

# %%
from src.odes import euler

f = lambda t, y: y
t, y = euler(f, 0, 1, 0.1, 10)
y
